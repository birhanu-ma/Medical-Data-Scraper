# %%
import os
import sys
from dotenv import load_dotenv
# Step 1 — Go up one level (from /notebooks/bank_reviews → project_root)
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.append(project_root)


# 2. Import your class from the .py file
from src.yolo_detect import YOLOAnalyzer
# Out:
# Creating new Ultralytics Settings v0.0.6 file
# View Ultralytics Settings with 'yolo settings' or at 'C:\Users\Birhanu Matebe\AppData\Roaming\Ultralytics\settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# 1. Initialize the analyzer
analyzer = YOLOAnalyzer(model_name='yolov8n.pt')

# 2. Run detection on your image directory
# Make sure this path is correct relative to your notebook location
image_folder = "../data/raw/images"
detections_df = analyzer.detect_objects(image_folder)

# 3. Save and Display
if detections_df is not None:
    analyzer.save_results(detections_df, "../data/image_detections.csv")
    
    # Show the first 5 rows in the notebook
    display(detections_df.head())
    
    # Quick Summary: How many images fell into each category?
    print("\n--- Image Category Summary ---")
    print(detections_df['image_category'].value_counts())
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8n.pt to 'yolov8n.pt': 100% ━━━━━━━━━━━━ 6.2MB 159.0KB/s 40.2s.2s<1.3ss29.5s
# YOLO model yolov8n.pt initialized.
# Starting detection on 1547 images...
# Detection results saved to ../data/image_detections.csv
#    message_id                                  detected_objects  \
# 0          10                                              none
# 1          11                                             clock
# 2          13  hot dog, donut, hot dog, donut, hot dog, hot dog
# 3          14                                              none
# 4          15                                              none
#
#    confidence_score image_category                           image_path
# 0            0.0000          other  ../data/raw/images\CheMed123\10.jpg
# 1            0.4273          other  ../data/raw/images\CheMed123\11.jpg
# 2            0.5039          other  ../data/raw/images\CheMed123\13.jpg
# 3            0.0000          other  ../data/raw/images\CheMed123\14.jpg
# 4            0.0000          other  ../data/raw/images\CheMed123\15.jpg
# --- Image Category Summary ---
# image_category
# other              929
# product_display    415
# lifestyle          178
# promotional         25
# Name: count, dtype: int64
