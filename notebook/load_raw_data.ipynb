# %%
import os
import sys
from dotenv import load_dotenv
# Step 1 — Go up one level (from /notebooks/bank_reviews → project_root)
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.append(project_root)


# 2. Import your class from the .py file
from src.load_to_postgres import TelegramDataLoader

# %%
# 1. Initialize the loader (no arguments needed now!)
loader = TelegramDataLoader()

# 2. Execute the process
loader.run_pipeline(
    folder_path="../data/raw/telegram_messages/2026-01-18", 
    table_name="telegram_messages", 
    schema="raw"
)
# Out:
# Loader initialized with engine: medical_warehouse
# Successfully read 2076 records.
# Successfully loaded 2076 records into raw.telegram_messages
