# %%
import os
import sys
from dotenv import load_dotenv
# Step 1 — Go up one level (from /notebooks/bank_reviews → project_root)
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.append(project_root)


# 2. Import your class from the .py file
from src.scraper import TelegramScraper

# %%
# 3. Load Environment Variables
load_dotenv()
API_ID = os.getenv('API_ID')
API_HASH = os.getenv('API_HASH')
CHANNELS = ['t.me/CheMed123', 't.me/lobelia4cosmetics', 't.me/tikvahpharma']

# 4. Initialize and Run
scraper = TelegramScraper(API_ID, API_HASH)
await scraper.run(CHANNELS) # Using 10 for a quick test
# Out:
# ✅ CheMed123: Saved to c:\Users\Birhanu Matebe\Downloads\KAIM\MedicalData\Medical-Data-Scraper\data\raw\telegram_messages\2026-01-18\CheMed123.json
# ✅ lobelia4cosmetics: Saved to c:\Users\Birhanu Matebe\Downloads\KAIM\MedicalData\Medical-Data-Scraper\data\raw\telegram_messages\2026-01-18\lobelia4cosmetics.json
# ✅ tikvahpharma: Saved to c:\Users\Birhanu Matebe\Downloads\KAIM\MedicalData\Medical-Data-Scraper\data\raw\telegram_messages\2026-01-18\tikvahpharma.json
